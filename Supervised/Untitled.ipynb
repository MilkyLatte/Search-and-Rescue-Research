# %%
import pickle
import matplotlib.pyplot as plt

# %%
f = open('test/historyCentric.pckl', 'rb')
history = pickle.load(f)
f.close()

# %%
plt.plot(history['accuracy'])

# %%
plt.plot(history['loss'])

# %%
max(history['accuracy'])
# Out:
# 0.9831086481590025
