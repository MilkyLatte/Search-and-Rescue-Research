# %%
import pickle
import matplotlib.pyplot as plt

# %%
f = open('test/12x12TSPLevel2.pckl', 'rb')
history = pickle.load(f)
f.close()

# %%
plt.plot(history['accuracy'])

# %%
plt.plot(history['loss'])

# %%
max(history['accuracy'])
# Out:
# 0.9601134286085996
